# %% [markdown]
# <a href="https://colab.research.google.com/github/eljaysmith/Data-Science-Bootcamp-2026/blob/main/DSBootcamp_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
this is an addition to this notebook

# %% [markdown]
# This is an initial notebook to get setup.
